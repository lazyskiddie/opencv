# %%
import cv2

image = cv2.imread("sandeep.jpeg", 0)
print(image)
# Out:
# [[241 241 241 ... 242 242 242]
#  [241 241 241 ... 242 242 242]
#  [241 241 241 ... 242 242 242]
#  ...
#  [222 221 220 ... 208 208 209]
#  [222 221 220 ... 208 208 209]
#  [222 221 220 ... 208 208 209]]
